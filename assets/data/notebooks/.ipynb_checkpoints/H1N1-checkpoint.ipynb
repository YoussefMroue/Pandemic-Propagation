# %%
import os
import pandas as pd
import numpy as np
import operator
import datetime

# %%
h1file = os.path.join('..','rawData',"H1N1-Data.csv")
rawh1 = pd.read_csv(h1file,header= 0,encoding= 'ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6cb5040bf482> in <module>
#       1 h1file = os.path.join("H1N1-Data.csv")
# ----> 2 rawh1 = pd.read_csv(h1file,header= 0,encoding= 'ISO-8859-1')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'H1N1-Data.csv' does not exist: b'H1N1-Data.csv'

# %%
rawh1case = rawh1
rawh1case.drop(['Deaths'], axis = 1)
rawh1case = rawh1case[['Update Time','Country','Cases']]
rawh1case = rawh1case.reindex(index = rawh1case.index[::-1])
rawh1case = rawh1case.reset_index()
rawh1case = rawh1case.drop(['index'],axis = 1)
rawh1case = rawh1case[rawh1case.Country != "Grand Total"]
rawh1case

# %%
rawh1case.loc[rawh1case.Country == "Costa Rica*", "Country"] = "Costa Rica"

# %%
dates =(rawh1case['Update Time'])
dates = dates.drop_duplicates()
dates = dates.transpose()
dates = dates.values.tolist()
countries = pd.DataFrame(rawh1case['Country'])
countries = countries.drop_duplicates(subset = 'Country')
countries = countries.reset_index()
countries = countries.drop(['index'], axis = 1)
template = countries
template.head()

# %%
for i in range(len(dates)):
    template[dates[i]] = ""
template = template.set_index('Country')

# %%
for index, row in rawh1case.iterrows():
     template.loc[row[1],row[0]] = row[2]

# %%
template.head()

# %%
dates = template.columns
dates = pd.to_datetime(dates)
dates = dates.strftime('%m-%d-%Y')
template.columns = dates
dates = [datetime.datetime.strptime(date, '%m-%d-%Y').date() for date in dates]
for i in range(5):
    for dif in range(len(dates)):
        if (dates[dif+1]-dates[dif]).days>1:
            addme = dates[dif] + datetime.timedelta(days=1)
            dates.insert(dif+1, addme)
dates = [date_obj.strftime('%m-%d-%Y') for date_obj in dates]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f45bc8d7565> in <module>
# ----> 1 dates = template.columns
#       2 dates = pd.to_datetime(dates)
#       3 dates = dates.strftime('%m-%d-%Y')
#       4 template.columns = dates
#       5 dates = [datetime.datetime.strptime(date, '%m-%d-%Y').date() for date in dates]
#
# NameError: name 'template' is not defined

# %%
for i in range(len(dates)):
    if dates[i] != template.columns[i]:
        template.insert(loc = i,column = dates[i],value = template[template.columns[i-1]].tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0293d0b51fc4> in <module>
# ----> 1 for i in range(len(dates)):
#       2     if dates[i] != template.columns[i]:
#       3         template.insert(loc = i,column = dates[i],value = template[template.columns[i-1]].tolist())
#
# NameError: name 'dates' is not defined

# %%
template.head()
# Out:
#                          05-23-2009 05-24-2009 05-25-2009 05-26-2009  \
# Country
# United States of America       6552       6552       6552       6764
# United Kingdom                  117        117        122        137
# Turkey                            2          2          2          2
# Thailand                          2          2          2          2
# Switzerland                       2          2          3          3
#
#                          05-27-2009 05-28-2009 05-29-2009 05-30-2009  \
# Country
# United States of America       6764       6764       7927       7927
# United Kingdom                  137        137        203        203
# Turkey                            2          2          2          2
# Thailand                          2          2          2          2
# Switzerland                       3          3          4          4
#
#                          05-31-2009 06-01-2009  ... 06-27-2009 06-28-2009  \
# Country                                         ...
# United States of America       7927       8975  ...      21449      21449
# United Kingdom                  203        229  ...       3597       3597
# Turkey                            2          4  ...         26         26
# Thailand                          2          2  ...        774        774
# Switzerland                       4          8  ...         47         47
#
#                          06-29-2009 06-30-2009 07-01-2009 07-02-2009  \
# Country
# United States of America      27717      27717      27717      27717
# United Kingdom                 4250       4250       6538       6538
# Turkey                           27         27         32         32
# Thailand                        774        774       1414       1414
# Switzerland                      49         49         56         56
#
#                          07-03-2009 07-04-2009 07-05-2009 07-06-2009
# Country
# United States of America      33902      33902      33902      33902
# United Kingdom                 7447       7447       7447       7447
# Turkey                           40         40         40         40
# Thailand                       1414       1414       1414       2076
# Switzerland                      72         72         72         76
#
# [5 rows x 45 columns]

# %%
days = []
for x in range(len(template.columns)):
    days.append('Day '+str(x))
template.columns = days

# %%
new_temp = template.copy()
new_temp.head()
# Out:
#                          Day 0 Day 1 Day 2 Day 3 Day 4 Day 5 Day 6 Day 7  \
# Country
# United States of America  6552  6552  6552  6764  6764  6764  7927  7927
# United Kingdom             117   117   122   137   137   137   203   203
# Turkey                       2     2     2     2     2     2     2     2
# Thailand                     2     2     2     2     2     2     2     2
# Switzerland                  2     2     3     3     3     3     4     4
#
#                          Day 8 Day 9  ... Day 35 Day 36 Day 37 Day 38 Day 39  \
# Country                               ...
# United States of America  7927  8975  ...  21449  21449  27717  27717  27717
# United Kingdom             203   229  ...   3597   3597   4250   4250   6538
# Turkey                       2     4  ...     26     26     27     27     32
# Thailand                     2     2  ...    774    774    774    774   1414
# Switzerland                  4     8  ...     47     47     49     49     56
#
#                          Day 40 Day 41 Day 42 Day 43 Day 44
# Country
# United States of America  27717  33902  33902  33902  33902
# United Kingdom             6538   7447   7447   7447   7447
# Turkey                       32     40     40     40     40
# Thailand                   1414   1414   1414   1414   2076
# Switzerland                  56     72     72     72     76
#
# [5 rows x 45 columns]

# %%
new_temp.insert(0,"Latitude","")
new_temp.insert(1,"Longitude","")

# %%
new_temp.head()
# Out:
#                          Latitude Longitude Day 0 Day 1 Day 2 Day 3 Day 4  \
# Country
# United States of America                     6552  6552  6552  6764  6764
# United Kingdom                                117   117   122   137   137
# Turkey                                          2     2     2     2     2
# Thailand                                        2     2     2     2     2
# Switzerland                                     2     2     3     3     3
#
#                          Day 5 Day 6 Day 7  ... Day 35 Day 36 Day 37 Day 38  \
# Country                                     ...
# United States of America  6764  7927  7927  ...  21449  21449  27717  27717
# United Kingdom             137   203   203  ...   3597   3597   4250   4250
# Turkey                       2     2     2  ...     26     26     27     27
# Thailand                     2     2     2  ...    774    774    774    774
# Switzerland                  3     4     4  ...     47     47     49     49
#
#                          Day 39 Day 40 Day 41 Day 42 Day 43 Day 44
# Country
# United States of America  27717  27717  33902  33902  33902  33902
# United Kingdom             6538   6538   7447   7447   7447   7447
# Turkey                       32     32     40     40     40     40
# Thailand                   1414   1414   1414   1414   1414   2076
# Switzerland                  56     56     72     72     72     76
#
# [5 rows x 47 columns]

# %%
coords_file = os.path.join("coords.csv")
coords = pd.read_csv(h1file,header= 0,encoding= 'ISO-8859-1')

# %%
coords
# Out:
#                        Country  Cases  Deaths     Update Time
# 0                      Algeria      5     0.0   7/6/2009 9:00
# 1          Antigua and Barbuda      2     0.0   7/6/2009 9:00
# 2                    Argentina   2485    60.0   7/6/2009 9:00
# 3                    Australia   5298    10.0   7/6/2009 9:00
# 4                      Austria     19     0.0   7/6/2009 9:00
# ...                        ...    ...     ...             ...
# 1817                  Thailand      2     0.0  5/23/2009 8:00
# 1818                    Turkey      2     0.0  5/23/2009 8:00
# 1819            United Kingdom    117     0.0  5/23/2009 8:00
# 1820  United States of America   6552     9.0  5/23/2009 8:00
# 1821               Grand Total  12022    86.0  5/23/2009 8:00
#
# [1822 rows x 4 columns]
